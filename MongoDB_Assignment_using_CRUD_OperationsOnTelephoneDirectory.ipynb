# %% [markdown]
# Telephone Directory CRUD Operation

# %% [markdown]
# Install pymongo

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pymongo) (2.2.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# import pymongo module

# %%
import pymongo

# %% [markdown]
# importing pprint module

# %%
from pprint import pprint

# %% [markdown]
# Connecting MongoDB with python

# %%
client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")

# %% [markdown]
# listing all databases available

# %%
my_dbs = client.list_database_names()
pprint(my_dbs)
# Out:
# ['GUVI', 'GUVI_Telephone', 'Student', 'admin', 'config', 'local']

# %% [markdown]
# Creating a database

# %%
db = client["GUVI_Telephone"]

# %% [markdown]
# Creating a collection

# %%
telephone = db["Telephone"]

# %% [markdown]
# listing all the collections in "GUVI_Telephone" database

# %%
db_collections = db.list_collection_names()          # will show empty because we have not inserted any data to it.
pprint(db_collections)
# Out:
# ['Telephone']

# %% [markdown]
# inserting documents in "Telephone" collection

# %% [markdown]
# using insert_one() method

# %%
customer1 = telephone.insert_one({"name": "Vinie", "phone_no": 9812345670, "network": "vi", "address": "123, lodhi road", "city" :"new delhi"})
pprint(customer1)
pprint(customer1.inserted_id)
# Out:
# <pymongo.results.InsertOneResult object at 0x000002A38BFA3A00>
# ObjectId('63b5b65879a15cc2b2c0b831')

# %% [markdown]
# inserting multiple documents using insert_many() method

# %%
data =[{"name": "Vinod", "phone_no": 985678890, "network": "airtel", "address": "65, pusa road", "city": "new delhi"},
            {"name": "Vicky", "phone_no": 9123450767, "network": "airtel", "address": "78, Tilak nagar", "city": "west delhi"},
            {"name": "Sahil", "phone_no": 9765432190, "network": "vi", "address": "61, jorbagh", "city": " south delhi"},
            {"name": "Raj", "phone_no": 9808654321, "network": "vi", "address": "674, ashram", "city": "south delhi"},
            {"name": "Ambu", "phone_no": 9657543210, "network": "bsnl", "address": "712, malviya nagar", "city": "south delhi"},
            {"name": "Rani", "phone_no": 9678900098, "network": "airtel", "address": "12, jorbagh", "city": "south delhi"},
            {"name": "Ankit", "phone_no": 9800067812, "network": "jio", "address": "65, pusa road", "city": "new delhi"},
            {"name": "Monika", "phone_no": 9812347865, "network": "jio", "address": "54, kotla", "city": "new delhi"},
            {"name": "Anjali", "phone_no": 9564329100, "network": "jio", "address": "45, defence colony", "city": "new delhi"},
            {"name": "Vinod", "phone_no": 9800111234, "network": "vi", "address": "65, chandni chawk", "city": "old delhi"},
            {"name": "Kajal", "phone_no": 7654389765, "network": "airtel", "address": "82, lajpat nagar", "city": "new delhi"},
            {"name": "Amit", "phone_no": 7654321890, "network": "vi", "address": "432, laxmi nagar", "city": "east delhi"},
            {"name": "Vinod", "phone_no": 7567890909, "network": "airtel", "address": "145,lodhi complex", "city": "new delhi"}]

# %%
customers = telephone.insert_many(data)
pprint(customers)
pprint(customers.inserted_ids)
# Out:
# <pymongo.results.InsertManyResult object at 0x000002A38BF883D0>
# [ObjectId('63b5b63e79a15cc2b2c0b824'),
#  ObjectId('63b5b63e79a15cc2b2c0b825'),
#  ObjectId('63b5b63e79a15cc2b2c0b826'),
#  ObjectId('63b5b63e79a15cc2b2c0b827'),
#  ObjectId('63b5b63e79a15cc2b2c0b828'),
#  ObjectId('63b5b63e79a15cc2b2c0b829'),
#  ObjectId('63b5b63e79a15cc2b2c0b82a'),
#  ObjectId('63b5b63e79a15cc2b2c0b82b'),
#  ObjectId('63b5b63e79a15cc2b2c0b82c'),
#  ObjectId('63b5b63e79a15cc2b2c0b82d'),
#  ObjectId('63b5b63e79a15cc2b2c0b82e'),
#  ObjectId('63b5b63e79a15cc2b2c0b82f'),
#  ObjectId('63b5b63e79a15cc2b2c0b830')]

# %% [markdown]
# importing pprint module

# %%
from pprint import pprint

# %% [markdown]
# print all the records from "Telephone" collection

# %%
for documents in telephone.find():
    pprint(documents)
# Out:
# {'_id': ObjectId('63b5b4cb79a15cc2b2c0b814'),
#  'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b815'),
#  'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b816'),
#  'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b817'),
#  'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b818'),
#  'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b819'),
#  'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b81a'),
#  'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b81b'),
#  'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b81c'),
#  'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b81d'),
#  'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b81e'),
#  'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b81f'),
#  'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b820'),
#  'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'_id': ObjectId('63b5b4f579a15cc2b2c0b821'),
#  'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}

# %% [markdown]
# update records

# %% [markdown]
# update_one()method

# %%
old_data = {"name":"Vinie"}
new_data = {"$set": {"name":"vinodhini"}}
telephone.update_one(old_data,new_data)

for document in telephone.find({},{"_id":0}):
    pprint(document)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}

# %%
old_data = {"name":"Monika"}
#updating 2 field together
new_data = {"$set": {"network":"airtel", "address":"654, ashram"}}
telephone.update_one(old_data,new_data)

for document in telephone.find({},{"_id":0}):
  pprint(document)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}

# %%
old_data = {"name":"Raj"}
new_data = {"$set": {"phone_no":9000001234,"age":32}} 
# updating phone_no and adding one more field "age" which does not exist in it already.
telephone.update_one(old_data,new_data)

for document in telephone.find({},{"_id":0}):
  pprint(document)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'age': 32,
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9000001234}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}

# %%
#updating  a field by giving multiple conditions
old_data = {"name":"Ankit", "phone_no":9800067812}
new_data = {"$set": {"network":"airtel"}}
telephone.update_one(old_data,new_data)

for document in telephone.find({},{"_id":0}):
  pprint(document)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'age': 32,
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9000001234}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'airtel',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '712, malviya nagar',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'bsnl',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}

# %% [markdown]
# update_many() method

# %%
old_data = {"name":"Ambu"}
new_data = {"$set": {"network":"vi", "address":"60,lodhi road"}}
telephone.update_many(old_data,new_data)

for document in telephone.find({},{"_id":0}):
  pprint(document)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'age': 32,
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9000001234}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'airtel',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'vi',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}

# %%
# update_many() by giving multiple conditions and adding a new field
old_data = {"name":"Sahil"}
new_data = {"$set": {"network":"bsnl", "age":23}}
telephone.update_many(old_data,new_data)

for document in telephone.find({},{"_id":0}):
  pprint(document)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'age': 23,
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'bsnl',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'age': 32,
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9000001234}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'airtel',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'age': 23,
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'bsnl',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '82, lajpat nagar',
#  'city': 'new delhi',
#  'name': 'Kajal',
#  'network': 'airtel',
#  'phone_no': 7654389765}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}

# %% [markdown]
# delete records

# %% [markdown]
# using delete_one()method

# %%
telephone.delete_one({"name":"Kajal"})
for documents in telephone.find({},{"_id":0}):
    pprint(documents)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'age': 23,
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'bsnl',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'age': 32,
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9000001234}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'airtel',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '78, Tilak nagar',
#  'city': 'west delhi',
#  'name': 'Vicky',
#  'network': 'airtel',
#  'phone_no': 9123450767}
# {'address': '61, jorbagh',
#  'age': 23,
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'bsnl',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}

# %% [markdown]
# using delete_many()

# %%
telephone.delete_many({"name":"Vicky"})
for documents in telephone.find({},{"_id":0}):
    pprint(documents)
# Out:
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'vinodhini',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '61, jorbagh',
#  'age': 23,
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'bsnl',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'age': 32,
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9000001234}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'airtel',
#  'phone_no': 9800067812}
# {'address': '654, ashram',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'airtel',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 985678890}
# {'address': '61, jorbagh',
#  'age': 23,
#  'city': ' south delhi',
#  'name': 'Sahil',
#  'network': 'bsnl',
#  'phone_no': 9765432190}
# {'address': '674, ashram',
#  'city': 'south delhi',
#  'name': 'Raj',
#  'network': 'vi',
#  'phone_no': 9808654321}
# {'address': '60,lodhi road',
#  'city': 'south delhi',
#  'name': 'Ambu',
#  'network': 'vi',
#  'phone_no': 9657543210}
# {'address': '12, jorbagh',
#  'city': 'south delhi',
#  'name': 'Rani',
#  'network': 'airtel',
#  'phone_no': 9678900098}
# {'address': '65, pusa road',
#  'city': 'new delhi',
#  'name': 'Ankit',
#  'network': 'jio',
#  'phone_no': 9800067812}
# {'address': '54, kotla',
#  'city': 'new delhi',
#  'name': 'Monika',
#  'network': 'jio',
#  'phone_no': 9812347865}
# {'address': '45, defence colony',
#  'city': 'new delhi',
#  'name': 'Anjali',
#  'network': 'jio',
#  'phone_no': 9564329100}
# {'address': '65, chandni chawk',
#  'city': 'old delhi',
#  'name': 'Vinod',
#  'network': 'vi',
#  'phone_no': 9800111234}
# {'address': '432, laxmi nagar',
#  'city': 'east delhi',
#  'name': 'Amit',
#  'network': 'vi',
#  'phone_no': 7654321890}
# {'address': '145,lodhi complex',
#  'city': 'new delhi',
#  'name': 'Vinod',
#  'network': 'airtel',
#  'phone_no': 7567890909}
# {'address': '123, lodhi road',
#  'city': 'new delhi',
#  'name': 'Vinie',
#  'network': 'vi',
#  'phone_no': 9812345670}
